# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### Beispiele

# %%
df = pd.read_csv("../data/Library_Usage_withMembershipDuration.csv", low_memory=False)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Definition',
#        'Circulation Active Month', 'Circulation Active Year',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Within San Francisco County', 'is_adult',
#        'log_renewals', 'Membership Duration'],
#       dtype='object')

# %%
df.loc[df['Total Checkouts'] > 10000]
# Out:
#         Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 12694        12694                 Senior            12233            5416
# 12925        12925                 Senior            10428            1079
# 54102        54102                 Senior            17663              56
# 54414        54414                 Senior            12675            1422
# 59475        59475                 Senior            11252            2628
# ...            ...                    ...              ...             ...
# 293994      293994                  Adult            39743             659
# 294100      294100                  Adult            10454            8663
# 306622      306622                  Adult            10065            3897
# 312053      312053                  Adult            14825            3915
# 328352      328352                  Adult            12122             122
#
# ...

# %%
# Alternative: Hilfsvariable erstellen, die den booleschen Vektor zwischenspeichert
row_filter = df['Total Checkouts'] > 10000
df.loc[row_filter]
# Out:
#         Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 12694        12694                 Senior            12233            5416
# 12925        12925                 Senior            10428            1079
# 54102        54102                 Senior            17663              56
# 54414        54414                 Senior            12675            1422
# 59475        59475                 Senior            11252            2628
# ...            ...                    ...              ...             ...
# 293994      293994                  Adult            39743             659
# 294100      294100                  Adult            10454            8663
# 306622      306622                  Adult            10065            3897
# 312053      312053                  Adult            14825            3915
# 328352      328352                  Adult            12122             122
#
# ...

# %%
# Filter von Zeilen mit dem Wert 'Senior' in der Spalte 'Patron Type Definition' und dem Wert 'Email' in der Spalte 'Notice Preference Definition'
row_filter = (df['Patron Type Definition'] == 'Senior') & (df['Notice Preference Definition'] == 'Email')
df.loc[row_filter]
# Out:
#         Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                0                 Senior                5               0
# 5                5                 Senior                0               0
# 27              27                 Senior                0               0
# 28              28                 Senior                0               0
# 29              29                 Senior                0               0
# ...            ...                    ...              ...             ...
# 450101      450101                 Senior                0               0
# 450102      450102                 Senior                0               0
# 450142      450142                 Senior                0               0
# 450143      450143                 Senior                0               0
# 450144      450144                 Senior                1               0
#
# ...

# %%
filter1 = (df['Total Checkouts'] >= 20) & (df['Total Checkouts'] <= 80)

# %%
filter1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 450354    False
# 450355    False
# 450356    False
# 450357    False
# 450358    False
# Name: Total Checkouts, Length: 450359, dtype: bool

# %%
filter2 =  df['Total Checkouts'].between(20, 80)

# %%
filter2
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 450354    False
# 450355    False
# 450356    False
# 450357    False
# 450358    False
# Name: Total Checkouts, Length: 450359, dtype: bool

# %%
all(filter1 == filter2)
# Out:
# True

# %% [markdown]
# ###### Aufgaben

# %%
df['Patron Type Definition'].unique()
# Out:
# array(['Senior', 'Adult', 'Welcome', 'Teacher Card', 'Juvenile', 'Teen',
#        'Digital Access Card', 'At User Adult', 'Visitor', 'Retired Staff',
#        'At User Teen', 'At User Senior', 'Library By Mail',
#        'At User Welcome', 'At User Juvenile', 'Bibliocommons', 'Business'],
#       dtype=object)

# %%
df.loc[df['Patron Type Definition'] == ("Juvenile" or "At User Juvenile")]
# Out:
#         Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 1487          1487               Juvenile                0               0
# 1488          1488               Juvenile                0               0
# 1489          1489               Juvenile                0               0
# 1490          1490               Juvenile                3               9
# 1491          1491               Juvenile                0               0
# ...            ...                    ...              ...             ...
# 450243      450243               Juvenile                0               0
# 450244      450244               Juvenile                2               2
# 450245      450245               Juvenile                0               0
# 450246      450246               Juvenile                2               2
# 450247      450247               Juvenile               11              15
#
# ...

# %%
# Filter: Kindern unter 10 Jahren
filter_kind10 = (df['Patron Type Definition'] == "Juvenile") & (df['Age Range'] == "0 to 9 years")

# %%
df.loc[filter_kind10]  # Anzahl Einträge: 33.013
# Out:
#         Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 1487          1487               Juvenile                0               0
# 1488          1488               Juvenile                0               0
# 1491          1491               Juvenile                0               0
# 1493          1493               Juvenile                0               0
# 1497          1497               Juvenile                0               0
# ...            ...                    ...              ...             ...
# 450241      450241               Juvenile                0               0
# 450244      450244               Juvenile                2               2
# 450245      450245               Juvenile                0               0
# 450246      450246               Juvenile                2               2
# 450247      450247               Juvenile               11              15
#
# ...

# %%
# Gibt es Personen mit mehr als 20000 Ausleihen? 
df.loc[df['Total Checkouts'] > 20000]  # Es gibt sieben Personen
# Out:
#         Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 60282        60282                 Senior            20561            1021
# 60622        60622                 Senior            23134             617
# 60994        60994                 Senior            21890              16
# 179460      179460                  Adult            35176              62
# 234329      234329                  Adult            23345            6458
# 234381      234381                  Adult            24386             387
# 293994      293994                  Adult            39743             659
#
#                 Age Range Home Library Definition  Circulation Active Month  \
# 60282      65 to 74 years                    Main                       3.0
# 60622      65 to 74 years                    Main                       3.0
# 60994   75 years and over                    Main                       1.0
# ...

# %%
# Wie viele Personen stammen aus dem Stadtteil (Richmond)?
df.loc[df['Home Library Definition'] == "Richmond"]  # Es gibt 21.433 Einträge
# Out:
#         Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 3                3                Welcome                1               1
# 228            228                 Senior                0               0
# 229            229                 Senior                0               0
# 230            230                 Senior                7              19
# 231            231                 Senior                0               0
# ...            ...                    ...              ...             ...
# 450159      450159                  Adult                0               0
# 450198      450198               Juvenile                0               0
# 450255      450255                   Teen                1               0
# 450256      450256                   Teen             1288             109
# 450291      450291    Digital Access Card                0               0
#
# ...

# %%
# Wie viele Prozent der Beobachtungen haben eine Membership Duration von Null Monaten?
df.loc[df['Membership Duration'] == 0] # Es gibt 40.317 Einträge
# Out:
#         Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 14              14           Teacher Card                0               0
# 17              17           Teacher Card                0               0
# 36              36                 Senior                0               0
# 93              93                 Senior                0               0
# 127            127                 Senior                0               0
# ...            ...                    ...              ...             ...
# 450321      450321    Digital Access Card                0               0
# 450324      450324    Digital Access Card                0               0
# 450339      450339    Digital Access Card                0               0
# 450340      450340    Digital Access Card                0               0
# 450354      450354    Digital Access Card                0               0
#
# ...

# %%
p_wert = len(df.loc[df['Membership Duration'] == 0])

# %%
p_wert
# Out:
# 40317

# %%
g_wert = len(df['Membership Duration'])

# %%
g_wert
# Out:
# 450359

# %%
prozent = (p_wert/g_wert) * 100

# %%
prozent
# Out:
# 8.952191473913034

# %%
round(prozent, 2)
# Out:
# 8.95
