# %%
import seaborn as sns
import pandas as pd
import numpy as np
sns.set_theme()

# %%
n = 1000
cor = [-0.99, -0.7, -0.5, -0.2, 0, 0.2, 0.5, 0.7, 0.99]
dat = pd.DataFrame()

# %%
for c in cor:
    covmat = np.array((1, c, c, 1)).reshape((2, 2))
    X = np.random.multivariate_normal([0,0], covmat, size=n)
    X = np.hstack((X, np.ones(n).reshape((n,1))*c))
    dat = dat.append(pd.DataFrame(X, columns=["x", "y", "correlation"]))

g = sns.FacetGrid(col="correlation", data=dat, col_wrap=3)
g.map(sns.scatterplot, "x", "y")
g
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20172\1277461874.py in ?()
#       1 for c in cor:
#       2     covmat = np.array((1, c, c, 1)).reshape((2, 2))
#       3     X = np.random.multivariate_normal([0,0], covmat, size=n)
#       4     X = np.hstack((X, np.ones(n).reshape((n,1))*c))
# ----> 5     dat = dat.append(pd.DataFrame(X, columns=["x", "y", "correlation"]))
#       6
#       7 g = sns.FacetGrid(col="correlation", data=dat, col_wrap=3)
#       8 g.map(sns.scatterplot, "x", "y")
#
# ~\miniforge3\envs\main\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# ...

# %%
for c in cor:
    covmat = np.array((1, c, c, 1)).reshape((2, 2))
    X = np.random.multivariate_normal([0,0], covmat, size=n)
    X = np.hstack((X, np.ones(n).reshape((n,1))*c))
    dat = pd.concat([dat, pd.DataFrame(X, columns=["x", "y", "correlation"])])

g = sns.FacetGrid(col="correlation", data=dat, col_wrap=3)
g.map(sns.scatterplot, "x", "y")
g

# %%
g.savefig('./correlation.png')

# %%
df = pd.read_csv("../data/Library_Usage.csv", low_memory=False)

# %%
df['Total Checkouts'].corr(df['Total Renewals'])
# Out:
# np.float64(0.6421628513121922)

# %% [markdown]
# ##### Aufgabe 3.8 - Exkurs Anscombe-Quartett

# %% [markdown]
# Das Anscombe Quartett ist ein Datenstatz, der aus 4 bivariaten Verteilungen besteht.
# Über die Spaltennamen ['x1', 'y1'], ['x2', 'y2'], ..., ['x4', 'y4'] können die zusammengehörenden Datenpaare ausgewählt werden.

# %% [markdown]
# 1. Lies den Datensatz ein.

# %%
df = pd.read_csv("../data/anscombe.csv")

# %%
df
# Out:
#     x1     y1  x2    y2  x3     y3  x4     y4
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89

# %% [markdown]
# 2. Berechne den Mittelwert, Median und die Standardabweichung der Spalten.

# %%
df['x1'].mean()
# Out:
# np.float64(9.0)

# %%
df['x2'].mean()
# Out:
# np.float64(9.0)

# %%
df['x3'].mean()
# Out:
# np.float64(9.0)

# %%
df['x4'].mean()
# Out:
# np.float64(9.0)

# %%
df['y1'].mean()
# Out:
# np.float64(7.500909090909093)

# %%
df['y2'].mean()
# Out:
# np.float64(7.50090909090909)

# %%
df['y3'].mean()
# Out:
# np.float64(7.5)

# %%
df['y4'].mean()
# Out:
# np.float64(7.500909090909091)

# %%
df['x1'].median()
# Out:
# 9.0

# %%
df['x2'].median()
# Out:
# 9.0

# %%
df['x3'].median()
# Out:
# 9.0

# %%
df['x4'].median()
# Out:
# 8.0

# %%
df['y1'].median()
# Out:
# 7.58

# %%
df['y2'].median()
# Out:
# 8.14

# %%
df['y3'].median()
# Out:
# 7.11

# %%
df['y4'].median()
# Out:
# 7.04

# %%
df['x1'].std()
# Out:
# 3.3166247903554

# %%
df['x2'].std()
# Out:
# 3.3166247903554

# %%
df['x3'].std()
# Out:
# 3.3166247903554

# %%
df['x4'].std()
# Out:
# 3.3166247903554

# %%
df['y1'].std()
# Out:
# 2.031568135925815

# %%
df['y2'].std()
# Out:
# 2.0316567355016177

# %%
df['y3'].std()
# Out:
# 2.030423601123667

# %%
df['y4'].std()
# Out:
# 2.0305785113876023

# %% [markdown]
# 3. Berechne jeweils die Korrelation zweier zusammenhängender Spalten [x<i>, y<i>]

# %%
cor1 = df['x1'].corr(df['y1'])

# %%
cor2 = df['x2'].corr(df['y2'])

# %%
cor3 = df['x3'].corr(df['y3'])

# %%
cor4 = df['x4'].corr(df['y4'])

# %%
df_corr = pd.DataFrame({'correlation': [cor1, cor2, cor3, cor4]})

# %%
df_corr
# Out:
#    correlation
# 0     0.816421
# 1     0.816237
# 2     0.816287
# 3     0.816521

# %%
# sns.set_theme(style="ticks")

# %% [markdown]
# 4. Erstelle jeweils ein Streudiagram zweier zusammenhängender Spalten [x<i>, y<i>]

# %%
# df = sns.load_dataset("anscombe")

# %%
# sns.lmplot(
    data=df, x="x", y="y", col="dataset", hue="dataset",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": 1}
)
