# %%
import pandas as pd
import json
import lxml

# %%
df = pd.read_csv("../data/Library_Usage_Small.csv")

# %%
df
# Out:
#    Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 0           0                 Senior                5               0
# 1           1                  Adult                0               0
# 2           2                  Adult                0               0
# 3           3                Welcome                1               1
# 4           4                 Senior                0               0
# 5           5                 Senior                0               0
# 6           6                  Adult                0               0
# 7           7                  Adult                1               0
# 8           8                  Adult                4               4
# 9           9                  Adult                0               0
#
#            Age Range Home Library Definition Circulation Active Month  \
# 0  75 years and over                    Main                      Nov
# ...

# %%
df.to_json("../data/Library_Usage_Small.json")

# %%
df = pd.read_json("../data/Library_Usage_Small.json")

# %%
df

# %%
df.to_html("../data/Library_Usage_Small.html", index = False)

# %%
df_table = pd.read_html("../data/Library_Usage_Small.html")[0]

# %%
df_table = df_table[0]
# Out:
#    Unnamed: 0.1  Unnamed: 0 Patron Type Definition  Total Checkouts  \
# 0             0           0                 Senior                5
# 1             1           1                  Adult                0
# 2             2           2                  Adult                0
# 3             3           3                Welcome                1
# 4             4           4                 Senior                0
# 5             5           5                 Senior                0
# 6             6           6                  Adult                0
# 7             7           7                  Adult                1
# 8             8           8                  Adult                4
# 9             9           9                  Adult                0
#
#    Total Renewals          Age Range Home Library Definition  \
# 0               0  75 years and over                    Main
# 1               0     45 to 54 years                    Main
# ...

# %%
df_table

# %%
df_table.to_excel("../data/Library_Usage_Small.xlsx",  index = False)

# %%
df_table
# Out:
#    Unnamed: 0.1  Unnamed: 0 Patron Type Definition  Total Checkouts  \
# 0             0           0                 Senior                5
# 1             1           1                  Adult                0
# 2             2           2                  Adult                0
# 3             3           3                Welcome                1
# 4             4           4                 Senior                0
# 5             5           5                 Senior                0
# 6             6           6                  Adult                0
# 7             7           7                  Adult                1
# 8             8           8                  Adult                4
# 9             9           9                  Adult                0
#
#    Total Renewals          Age Range Home Library Definition  \
# 0               0  75 years and over                    Main
# 1               0     45 to 54 years                    Main
# ...

# %%
df_to_csv = pd.read_excel("../data/Library_Usage_Small.xlsx")

# %%
df_to_csv.to_csv("../data/Library_Usage_Small_final.csv")

# %%
df_to_csv.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Patron Type Definition  \
# 0             0             0           0                 Senior
# 1             1             1           1                  Adult
# 2             2             2           2                  Adult
# 3             3             3           3                Welcome
# 4             4             4           4                 Senior
#
#    Total Checkouts  Total Renewals          Age Range Home Library Definition  \
# 0                5               0  75 years and over                    Main
# 1                0               0     45 to 54 years                    Main
# 2                0               0     55 to 59 years        Western Addition
# 3                1               1     20 to 24 years                Richmond
# 4                0               0     65 to 74 years                  Sunset
#
#   Circulation Active Month  Circulation Active Year  \
# ...

# %% [markdown]
# Vergleich der ursprünglichen *.csv-Datei mit der Datei "Library_Usage_Small_final.csv":
# Während der Konvertierung sind drei neue Spalten mit der Bezeichnung "Unnamed: xx" entstanden, die vor der ersten Spalte in der Original-Datei eingefügt wurden
